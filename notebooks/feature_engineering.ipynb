# %%
import pandas as pd
import re
import numpy as np

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("../data/UpdatedResumeDataSet.csv")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (962, 2)
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
job_descriptions = {
    "Data Science": """
    Python Machine Learning Deep Learning Statistics SQL
    Data Analysis Pandas NumPy Scikit-learn Model Deployment
    """,

    "HR": """
    Recruitment Talent Acquisition Payroll Employee Engagement
    HR Operations Communication Performance Management
    """,

    "DevOps Engineer": """
    Docker Kubernetes AWS CI CD Linux Automation
    Cloud Infrastructure Monitoring DevOps Tools
    """,

    "Web Designing": """
    HTML CSS JavaScript UI UX Responsive Design
    Figma Bootstrap Web Layouts
    """,

    "Python Developer": """
    Python OOP Flask Django APIs Databases
    Backend Development REST Services
    """
}

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z ]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %%
def skill_match(resume, jd):
    resume_words = set(clean_text(resume).split())
    jd_words = set(clean_text(jd).split())

    if len(jd_words) == 0:
        return 0.0

    return len(resume_words & jd_words) / len(jd_words)

# %%
def keyword_overlap(resume, jd):
    resume_words = set(clean_text(resume).split())
    jd_words = set(clean_text(jd).split())
    return len(resume_words & jd_words)

# %%
def resume_length_score(resume):
    length = len(resume.split())
    return 1 if 100 <= length <= 800 else 0

# %%
experience_keywords = [
    "experience", "years", "worked", "intern",
    "project", "projects", "company", "role"
]

def experience_score(resume):
    text = clean_text(resume)
    return sum(text.count(word) for word in experience_keywords)

# %%
pip install sentence-transformers flask torch
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: flask in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (3.1.1)
# Requirement already satisfied: torch in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (2.9.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: scipy in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: colorama in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.7.14)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\anuradha singh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
bert_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
def bert_similarity(resume, jd):
    embeddings = bert_model.encode([resume, jd])
    return cosine_similarity(
        [embeddings[0]],
        [embeddings[1]]
    )[0][0]

# %%
features = []

for _, row in df.iterrows():
    resume = row["Resume"]
    category = row["Category"]
    jd = job_descriptions.get(category, "")

    features.append({
        "skill_match": skill_match(resume, jd),
        "keyword_overlap": keyword_overlap(resume, jd),
        "resume_length": resume_length_score(resume),
        "experience_score": experience_score(resume),
        "bert_similarity": bert_similarity(resume, jd)
    })

features_df = pd.DataFrame(features)
features_df.head()
# Out:
#    skill_match  keyword_overlap  resume_length  experience_score  \
# 0     0.785714               11              1                 5
# 1     0.357143                5              1                 4
# 2     0.500000                7              1                 4
# 3     0.500000                7              0                24
# 4     0.214286                3              0                 3
#
#    bert_similarity
# 0         0.500591
# 1         0.383120
# 2         0.387008
# 3         0.344844
# 4         0.338331

# %%
final_df = pd.concat([df, features_df], axis=1)
final_df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#    skill_match  keyword_overlap  resume_length  experience_score  \
# 0     0.785714               11              1                 5
# 1     0.357143                5              1                 4
# 2     0.500000                7              1                 4
# 3     0.500000                7              0                24
# 4     0.214286                3              0                 3
#
#    bert_similarity
# 0         0.500591
# 1         0.383120
# 2         0.387008
# 3         0.344844
# 4         0.338331

# %%
final_df.to_csv("../data/resume_features_bert.csv", index=False)
print("✅ Feature engineered dataset saved successfully")
# Out:
# ✅ Feature engineered dataset saved successfully

# %%
final_df.describe()
# Out:
#        skill_match  keyword_overlap  resume_length  experience_score  \
# count   962.000000       962.000000     962.000000        962.000000
# mean      0.095691         1.122661       0.728690         12.597713
# std       0.199205         2.381756       0.444867         12.332934
# min       0.000000         0.000000       0.000000          2.000000
# 25%       0.000000         0.000000       0.000000          4.000000
# 50%       0.000000         0.000000       1.000000          8.000000
# 75%       0.000000         0.000000       1.000000         17.000000
# max       0.785714        11.000000       1.000000         63.000000
#
#        bert_similarity
# count       962.000000
# mean          0.103116
# std           0.119364
# min          -0.064670
# 25%           0.022647
# 50%           0.070292
# 75%           0.123006
# max           0.517819
